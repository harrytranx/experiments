# %%
import yaml

# %%
with open('/data/users/tranx/fbsource/fbcode/assistant/multimodal/xlformers_llama4/projects/pretrain/sweeps/tranx/data_pt17.yaml', 'r') as file:
    data = yaml.safe_load(file)

# Display the parsed data
print(data)
# Out:
# {'data': ['llama4_stackexchange_split_v2_shuffled_train_no_user_data:0.2143,llama3_b3g_split_no_user_data:0.0454,llama_bespoke_arxiv_v2_no_user_data:0.4139,llama_bespoke_galactica_train_no_user_data:0.6109,llama_bespoke_llama3_scimag_no_user_data:1.3601,llama_bespoke_pdf_curated_scimag_20240708_en_shuffled_markdown_no_user_data:2.9265,llama_bespoke_pdf_curated_scimag_20240708_non_en_shuffled_markdown_no_user_data:0.5234,llama_bespoke_scitech_en_union_train_mitigated_no_user:2.6197,llama_bespoke_scitech_nonen_union_train_mitigated_no_user_data:1.7865,llama_bespoke_zlib_ia_stem_mitigated_no_user_data:0.4255,llama3_fiction_split_no_user_data:0.1523,llama3_fiction_rest_split_no_user_data:0.0067,llama3_fiction_nonen_split_no_user_data:0.126,annas_archive_scitech_2023_2024_epub_dedup_en_no_user_data:0.0585,annas_archive_scitech_2023_2024_epub_dedup_non_en_no_user_data:0.0204,annas_archive_zlib_epub_dedup_mitigated_en_no_user_data:0.1403,annas_archive_zlib_epub_dedup_mitigated_non_en_no_use
# ...

# %%
with open('/data/users/tranx/fbsource/fbcode/assistant/multimodal/xlformers_llama4/core/dataweave/datasets/all_image_datasets.py', 'r') as file:
    all_image = file.read()

# %%
data['data'][0]
# Out:
# 'llama4_stackexchange_split_v2_shuffled_train_no_user_data:0.2143,llama3_b3g_split_no_user_data:0.0454,llama_bespoke_arxiv_v2_no_user_data:0.4139,llama_bespoke_galactica_train_no_user_data:0.6109,llama_bespoke_llama3_scimag_no_user_data:1.3601,llama_bespoke_pdf_curated_scimag_20240708_en_shuffled_markdown_no_user_data:2.9265,llama_bespoke_pdf_curated_scimag_20240708_non_en_shuffled_markdown_no_user_data:0.5234,llama_bespoke_scitech_en_union_train_mitigated_no_user:2.6197,llama_bespoke_scitech_nonen_union_train_mitigated_no_user_data:1.7865,llama_bespoke_zlib_ia_stem_mitigated_no_user_data:0.4255,llama3_fiction_split_no_user_data:0.1523,llama3_fiction_rest_split_no_user_data:0.0067,llama3_fiction_nonen_split_no_user_data:0.126,annas_archive_scitech_2023_2024_epub_dedup_en_no_user_data:0.0585,annas_archive_scitech_2023_2024_epub_dedup_non_en_no_user_data:0.0204,annas_archive_zlib_epub_dedup_mitigated_en_no_user_data:0.1403,annas_archive_zlib_epub_dedup_mitigated_non_en_no_user_data:0.3
# ...

# %%
for item in data['data'][0].split(","):
    name, mult = item.split(":")
    if name in all_image:
        print(f"{name}:{mult},\\")
# Out:
# llama4_fennel_femto_0001_gaid_mathpix_pdf_long_context_sampled_embeddings_no_user_data:1.0228,\
# llama4_fennel_femto_0000_mmc4_wikipedia_fmm_sm_interleaved_with_embeddings_v2_no_user_data:0.3791,\
# llama4_0045_gaid_qa_captions_for_annealing_with_embeddings_v4_no_user_data:0.0384,\
# llama4_fennel_footlong_0000_web_caption_pt_v3_reid_with_embeddings_288b_no_user_data:0.1768,\
# llama4_fennel_footlong_0000_web_intent_pt_v1_reid_with_embeddings_288b_no_user_data:0.1326,\
# llama4_web_agent_osaltas_v0_rephrased_lct_embeddings_v2_no_user_data:0.1330,\
# llama4_0045_gaid_bespoke_afanti_qa_anonymized_en_ablation_with_embeddings_no_user_data:0.0412,\
# llama4_0045_gaid_bespoke_afanti_qa_anonymized_ablation_with_embeddings_no_user_data:0.0391,\
# llama4_fennel_footlong_0000_sg_ocr_with_embeddings_288b_no_user_data:0.5016,\
# llama4_fennel_footlong_0000_sg_qa_with_embeddings_288b_no_user_data:0.1369,\
# ...

# %%
all_image
# Out:
# 'from core.dataweave.datasets.config import ImageAIRStoreDatasetConfig\nfrom core.params.cluster import ClusterRegion\n\n# NOTE: The included token counts are approximate and assume that the following training setup is used.\n# - Sequence length: 2048 (sequence length affects tokens as smaller sequence length will have more padding)\n# - 12 tiles per image\n# - tiles of 336 x 336 pixels\n\nImageAIRStoreDatasetConfig(\n    dataset_name="test_retina_mitigated_shutterstock_filtered_with_embeddings_no_user_data_rsc",\n    airstore_dataset_static_length=207_751_540,\n    airstore_dataset_text_key="clean_sentence",\n    airstore_dataset_image_keys=["image"],\n    airstore_dataset_image_embeddings_key="image_embedding",\n    airstore_dataset_id_key="id_airstore",\n    airstore_dataset_image_count=207_751_540,\n    supported_regions=[ClusterRegion.PCI],\n)\n\ndataset_name = (\n    "test_retina_gaid_wit_20240628_snapshot_blurred_with_embeddings_no_user_data"\n)\nImageAIRStoreDatasetConfig(\n 
# ...

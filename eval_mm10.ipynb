# %%
# BOILER PLATE, MUST BE RUN ON SUBMIT NODE
# %load_ext autoreload
# %autoreload 2
import socket
print("Running on host: ", socket.gethostname())

import sys 
lib_path = '/fsx_0/user/tranx/experiments'
if lib_path not in sys.path:
    sys.path.append(lib_path)
#=================================================

from lib import eval_helper

ev_master = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync",
    # code_dir="/fsx_0/user/tranx/aws_prod",
    eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    # eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite"
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite"
)


ev_norm = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync_norm",
    # code_dir="/fsx_0/user/tranx/aws_prod",
    # eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    eval_sbatch="/fsx_0/user/tranx/experiments/eval/sbash_eval.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite"
)

ev_prod = eval_helper.EvalHelper(
    # code_dir="/fsx_0/user/tranx/rsync",
    code_dir="/fsx_0/user/tranx/aws_prod",
    eval_sbatch="/fsx_0/user/tranx/experiments/eval/sbash_eval.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite"
)

benchmark_non_mmmu = [b for b in eval_helper.ALL_BENCHMARKS if b != "mmmu"]
benchmark_non_mmmu
# Out:
# Running on host:  submit-1
# ['docvqa',
#  'mathvista',
#  'ai2d',
#  'chartqa',
#  'vqa',
#  'textvqa',
#  'infographics_w_ocr',
#  'infographics',
#  'mmbench']

# %% [markdown]
# # S2

# %%
OUTPUT_S2 = "/fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a"
OUTPUT_S2_16 = "/fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_bz48"
OUTPUT_S2_unfreeze = "/fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze"
OUTPUT_S2_30d = "/fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp30d_m2c2_036_unfreeze"

ev_s2 = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync",
    eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite"
)

ev_s2_unfreeze = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync",
    eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception"
)

# %%
ev_s2_unfreeze.run_eval_sweep(
    OUTPUT_S2_unfreeze,
    print_cmd=True,
    # benchmarks=["mmmu"],
    benchmarks=benchmark_non_mmmu,
    update_if_exists=True,
    checkpoints=[1300]
    # min_checkpoint=700
)
# Out:
# New checkpoints: [1300]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze/checkpoint-1300
# sbatch --parsable --job-name=eval_docvqa /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_docvqa.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze docvqa 1300 "" ""
# JOB ID: 40510
# sbatch --parsable --job-name=eval_mathvista /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_mathvista.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze mathvista 1300 "" ""
# JOB ID: 40511
# sbatch --parsable --job-name=eval_ai2d /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_ai2d.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze ai2d 1300 "" ""
# JOB ID: 40512
# sbatch --parsable --job-name=eval_chartqa /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_chartqa.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze chartqa 1300 "" ""
# JOB ID: 40513
# sbatch --parsable --job-name=eval_vqa /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_vqa.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze vqa 1300 "" ""
# JOB ID: 40514
# sbatch --parsable --job-name=eval_textvqa /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_textvqa.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze textvqa 1300 "" ""
# JOB ID: 40515
# sbatch --parsable --job-name=eval_infographics_w_ocr /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_infographics_w_ocr.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze infographics_w_ocr 1300 "" ""
# JOB ID: 40516
# sbatch --parsable --job-name=eval_infographics /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_infographics.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze infographics 1300 "" ""
# JOB ID: 40517
# sbatch --parsable --job-name=eval_mmbench /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite_w_checkpoints_perception/eval_mmbench.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze mmbench 1300 "" ""
# JOB ID: 40518
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a_unfreeze/evals/eval_jobs_checkpoint-1300.json

# %%
ev_s2_unfreeze.get_scores(OUTPUT_S2_30d)
# Out:
#      mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 3300  0.5867  0.5633  0.5516     0.438   0.807  0.4842  0.7187  0.65324
# 3400  0.5756  0.5567  0.6191     0.452  0.8018  0.4717  0.7146    0.651
# 3500    0.56  0.5389  0.6351     0.443  0.8083  0.4718  0.7189  0.65132
# 3600  0.5644  0.5444   0.639     0.439  0.8044  0.5006  0.7185   0.6513
# 3700  0.5533  0.5311  0.6524     0.439  0.8044  0.5166  0.7192  0.65002
# 3800  0.5544  0.5333  0.6541     0.425  0.7918  0.4987  0.7185  0.64394
# 3900  0.5667  0.5444   0.677     0.448  0.7976  0.4849   0.721  0.65828
# 4000  0.5722  0.5511  0.6779     0.443  0.7905  0.4752  0.7214   0.6494
# 4100  0.5789  0.5522  0.6663     0.431  0.7759  0.4746  0.7145   0.6604
# 4200  0.5689  0.5422  0.6674     0.431  0.8012   0.509   0.715  0.65648
# 4300  0.5822  0.5622   0.675     0.453  0.7983  0.4834  0.7172  0.65578
# 4400     NaN     NaN  0.6711     0.448   0.808  0.5296  0.7191  0.66336
# 4500     NaN     NaN     NaN     0.454  0.7976  0.5072  0.7215  0.66034
#
#      infographics_w_ocr infographics mmbench
# 3300             0.6467       0.5997  0.7058
# 3400             0.6528       0.6084  0.7077
# 3500             0.6485       0.5982  0.6956
# 3600             0.6461       0.6043  0.7063
# 3700             0.6388       0.5884  0.6971
# 3800             0.6441       0.5954  0.6933
# 3900             0.6506       0.6025  0.7013
# 4000             0.6515       0.5965  0.6904
# 4100             0.6537       0.5947  0.6976
# 4200             0.6444       0.5957  0.7153
# 4300              0.657        0.605  0.7105
# 4400             0.6519       0.5997  0.7043
# 4500             0.6564       0.6062  0.7098

# %%
ev_s2_unfreeze.get_scores(OUTPUT_S2_unfreeze)
# Out:
#      mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 600   0.5689  0.5489     NaN       NaN     NaN     NaN     NaN      NaN
# 700   0.5744  0.5556     NaN       NaN     NaN     NaN     NaN      NaN
# 800     0.58  0.5589     NaN       NaN     NaN     NaN     NaN      NaN
# 900   0.5867  0.5678     NaN       NaN     NaN     NaN     NaN      NaN
# 1000  0.5767  0.5633     NaN       NaN     NaN     NaN     NaN      NaN
# 1100  0.5711  0.5544     NaN       NaN     NaN     NaN     NaN      NaN
# 1200  0.5689  0.5489     NaN       NaN     NaN     NaN     NaN      NaN
# 1300  0.5922  0.5744  0.6325     0.409   0.771  0.4747  0.7144  0.64766
# 1400  0.5533  0.5311     NaN       NaN     NaN     NaN     NaN      NaN
# 1500  0.5644  0.5422     NaN       NaN     NaN     NaN     NaN      NaN
# 1600  0.5533  0.5389     NaN       NaN     NaN     NaN     NaN      NaN
# 1700  0.5689  0.5467  0.6031     0.416  0.7782  0.4732  0.7158  0.64926
# 1800  0.5422  0.5233  0.5946      0.44  0.7672  0.4616   0.709  0.65796
# 1900  0.5822  0.5667  0.5558      0.43  0.7581  0.4765    0.71   0.6473
# 2000  0.5678  0.5489  0.5834     0.422  0.7639  0.4855  0.7157   0.6473
# 2100  0.5678  0.5489   0.607     0.422   0.785  0.4898  0.7152  0.65192
# 2200  0.5767  0.5667   0.548     0.431  0.7665  0.4914  0.7168   0.6512
# 2300  0.5667  0.5422  0.5769     0.418  0.7859  0.4877  0.7172   0.6485
# 2400  0.5733  0.5522  0.6059     0.427   0.796  0.4768  0.7164  0.64548
# 2500  0.5689    0.55  0.5864     0.414  0.7866  0.4938  0.7119   0.6504
# 2600    0.58  0.5633  0.6151     0.424  0.7691   0.474  0.7147  0.64822
# 2700  0.5733  0.5567  0.5727     0.424  0.7902  0.4761   0.716  0.65184
# 2800  0.5622  0.5456  0.5639     0.443  0.7753  0.4583  0.7144  0.65254
# 2900  0.5689  0.5456  0.6177     0.431  0.7859  0.4721  0.7181  0.65492
# 3000  0.5633  0.5356  0.5803     0.418  0.7652  0.4629  0.7176  0.65066
# 3100  0.5711  0.5467  0.5498     0.411  0.7814  0.4814   0.717  0.65062
# 3200     0.6  0.5756  0.5353     0.437  0.7756  0.4787  0.7174  0.64652
# 3300    0.58  0.5567  0.5787      0.43  0.7843  0.4807  0.7175  0.64586
# 3400  0.5589  0.5389  0.5895     0.452  0.7856  0.4764  0.7146  0.65092
# 3500  0.5433  0.5256  0.5976     0.441  0.7817  0.4824  0.7168  0.65254
# 3600  0.5733  0.5622  0.6027     0.435  0.7863   0.491  0.7138  0.64698
# 3700  0.5711  0.5456  0.5592     0.435  0.7859  0.4808  0.7142  0.65706
# 3800  0.5622  0.5478  0.6104     0.441  0.7999  0.4973  0.7186  0.65592
#
#      infographics_w_ocr infographics mmbench
# 600                 NaN          NaN     NaN
# 700                 NaN          NaN     NaN
# 800                 NaN          NaN     NaN
# 900                 NaN          NaN     NaN
# 1000                NaN          NaN     NaN
# 1100                NaN          NaN     NaN
# 1200                NaN          NaN     NaN
# 1300             0.6475        0.599  0.6675
# 1400                NaN          NaN     NaN
# 1500                NaN          NaN     NaN
# 1600                NaN          NaN     NaN
# 1700              0.641       0.5874  0.6735
# 1800             0.6418       0.5898  0.6714
# 1900             0.6425       0.5974  0.6749
# 2000              0.647       0.5993   0.661
# 2100             0.6369       0.5924  0.6829
# 2200             0.6403       0.5955  0.6786
# 2300             0.6399       0.6012  0.6782
# 2400             0.6402       0.5841  0.6686
# 2500             0.6489       0.5981  0.6792
# 2600             0.6434       0.6006  0.6716
# 2700             0.6432       0.5987  0.6892
# 2800             0.6382       0.5973  0.6718
# 2900             0.6427       0.5979   0.685
# 3000             0.6434       0.6017  0.6901
# 3100             0.6472       0.5869  0.6876
# 3200             0.6435       0.6025  0.6904
# 3300              0.643       0.5994  0.6846
# 3400             0.6391        0.591  0.6896
# 3500             0.6396       0.5975  0.6899
# 3600             0.6538       0.6053  0.6829
# 3700             0.6317       0.5943  0.6841
# 3800             0.6444       0.6068  0.6852

# %%
# ev_s2.run_eval_sweep(
#     OUTPUT_S2, 
#     print_cmd=True,
#     benchmarks=["mmmu"],
#     update_if_exists=True
# )
# Out:
# New checkpoints: [100, 200]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a/checkpoint-100
# sbatch --parsable --job-name=eval_mmmu /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a mmmu 100 "" ""
# JOB ID: 39421
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a/evals/eval_jobs_checkpoint-100.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a/checkpoint-200
# sbatch --parsable --job-name=eval_mmmu /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a mmmu 200 "" ""
# JOB ID: 39422
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage2-70B/MH21_70B_336px_exp32a/evals/eval_jobs_checkpoint-200.json

# %%
ev_s2.get_scores(OUTPUT_S2)
# Out:
#     mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 100  0.5722  0.5478   0.619     0.376  0.7591  0.4802  0.6908  0.63156
# 200  0.5822  0.5578  0.6166     0.382  0.7685  0.5163  0.6989  0.65504
# 300    0.55  0.5378  0.6131     0.395  0.7788  0.5011  0.7041  0.65228
# 400    0.55  0.5356   0.609     0.381  0.7753  0.5072  0.7093   0.6549
# 500    0.58  0.5633  0.6041     0.403   0.784  0.5125  0.7102  0.65412
#
#     infographics_w_ocr infographics mmbench
# 100             0.6208       0.5723  0.6362
# 200              0.626       0.5747   0.664
# 300             0.6253       0.5731   0.673
# 400             0.6266        0.582  0.6639
# 500             0.6242       0.5687   0.669

# %%
ev_s2.get_scores(OUTPUT_S2_16)
# Out:
#     mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 100  0.5556  0.5289  0.5925     0.375  0.7568   0.444  0.6787  0.61718
# 200  0.5811  0.5589  0.6074      0.38  0.7555  0.4616  0.6921  0.63178
# 300  0.5533  0.5356  0.6266     0.376  0.7655  0.4881  0.6936  0.63686
# 400     NaN     NaN  0.6259     0.376   0.761  0.5199  0.6954  0.63878
# 500  0.5733    0.55  0.6073     0.362  0.7597   0.517  0.6886  0.64674
# 600  0.5478  0.5322  0.6289     0.371  0.7639  0.5332  0.7007  0.63756
# 700  0.5622  0.5389  0.6054     0.378  0.7723  0.5241  0.6958  0.63828
# 800  0.5644  0.5478  0.6026     0.379   0.771  0.5302  0.6952  0.64026
#
#     infographics_w_ocr infographics mmbench
# 100             0.6138       0.5576  0.6509
# 200             0.6258       0.5639  0.6484
# 300             0.6217        0.567  0.6431
# 400             0.6251       0.5702   0.652
# 500             0.6193       0.5605  0.6653
# 600             0.6266       0.5773  0.6595
# 700             0.6299       0.5854   0.669
# 800             0.6228       0.5719  0.6577

# %%
2*64*160
# Out:
# 20480

# %% [markdown]
# # S1

# %%
OUTPUT_S1 = "/fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916"
OUTPUT_S1_norm = "/fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm"
# BENCHMARKS = ["mathvista", "vqa"]
BENCHMARKS = ["mmmu"]

# %%
# ev.cancel_eval_jobs(OUTPUT_S1, cancel_states=['RUNNING'])
# Out:
# OrderedDict([('mmmu', OrderedDict([('100', 32814)]))])
# job 32814, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('200', 32815)]))])
# job 32815, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('300', 32816)]))])
# job 32816, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('400', 32817)]))])
# job 32817, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('500', 32818)]))])
# job 32818, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('600', 32819)]))])
# job 32819, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('700', 32820)]))])
# job 32820, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('800', 32821)]))])
# job 32821, state = COMPLETED
# OrderedDict([('mmmu', OrderedDict([('900', 35371)]))])
# job 35371, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1000', 35372)]))])
# job 35372, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1100', 35373)]))])
# job 35373, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1200', 35374)]))])
# job 35374, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1300', 35375)]))])
# job 35375, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1400', 35376)]))])
# job 35376, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1500', 35377)]))])
# OrderedDict([('mmmu', OrderedDict([('1600', 35378)]))])
# OrderedDict([('mmmu', OrderedDict([('1700', 35379)]))])
# OrderedDict([('mmmu', OrderedDict([('1800', 35380)]))])
# job 35380, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('1900', 35381)]))])
# job 35381, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('2000', 35382)]))])
# job 35382, state = PENDING
# OrderedDict([('mmmu', OrderedDict([('2100', 35383)]))])
# job 35383, state = PENDING

# %%
ev.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1,
    benchmarks=["mmmu"],
    slurm_qos="midpri",
    min_checkpoint=900,
    update_if_exists=False,
    print_cmd=True
)
# Out:
# New checkpoints: [3000]
# Start eval for /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916/checkpoint-3000
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 mmmu 3000
# eval jobs saved to: /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916/evals/eval_jobs_checkpoint-3000.json

# %%
ev.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1,
    benchmarks=[b for b in eval_helper.ALL_BENCHMARKS if b != 'mmmu'],
    slurm_qos="midpri",
    # min_checkpoint=900,
    checkpoints=[2800],
    update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [2800]
# Start eval for /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916/checkpoint-2800
# sbatch --parsable --job-name=eval_docvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_docvqa.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 docvqa 2800
# sbatch --parsable --job-name=eval_mathvista --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mathvista.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 mathvista 2800
# sbatch --parsable --job-name=eval_ai2d --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_ai2d.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 ai2d 2800
# sbatch --parsable --job-name=eval_chartqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_chartqa.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 chartqa 2800
# sbatch --parsable --job-name=eval_vqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_vqa.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 vqa 2800
# sbatch --parsable --job-name=eval_textvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_textvqa.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 textvqa 2800
# sbatch --parsable --job-name=eval_infographics_w_ocr --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_infographics_w_ocr.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 infographics_w_ocr 2800
# sbatch --parsable --job-name=eval_infographics --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_infographics.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 infographics 2800
# sbatch --parsable --job-name=eval_mmbench --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmbench.json /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916 mmbench 2800
# eval jobs saved to: /fsx_0/checkpoints/tranx/MM10-Pretrain-70B/MH21_70B_224px_0916/evals/eval_jobs_checkpoint-2800.json

# %%
ev.get_scores(OUTPUT_S1)
# Out:
#      mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 100   0.4078  0.3878     NaN       NaN     NaN     NaN     NaN      NaN
# 200   0.5167  0.4867     NaN       NaN     NaN     NaN     NaN      NaN
# 300   0.5011  0.4767     NaN       NaN     NaN     NaN     NaN      NaN
# 400   0.4956  0.4767     NaN       NaN     NaN     NaN     NaN      NaN
# 500   0.5122  0.4856     NaN       NaN     NaN     NaN     NaN      NaN
# 600   0.5089  0.4822     NaN       NaN     NaN     NaN     NaN      NaN
# 700   0.5333  0.5078     NaN       NaN     NaN     NaN     NaN      NaN
# 800   0.5378  0.5178     NaN       NaN     NaN     NaN     NaN      NaN
# 900   0.5389  0.5211     NaN       NaN     NaN     NaN     NaN      NaN
# 1000  0.5244  0.5089     NaN       NaN     NaN     NaN     NaN      NaN
# 1100  0.5322  0.5167     NaN       NaN     NaN     NaN     NaN      NaN
# 1200  0.5433    0.52     NaN       NaN     NaN     NaN     NaN      NaN
# 1300  0.5478  0.5189     NaN       NaN     NaN     NaN     NaN      NaN
# 1400  0.5378  0.5233     NaN       NaN     NaN     NaN     NaN      NaN
# 1500  0.5389  0.5222     NaN       NaN     NaN     NaN     NaN      NaN
# 1600  0.5489  0.5278     NaN       NaN     NaN     NaN     NaN      NaN
# 1700  0.5378  0.5122     NaN       NaN     NaN     NaN     NaN      NaN
# 1800  0.5344  0.5156     NaN       NaN     NaN     NaN     NaN      NaN
# 1900  0.5544  0.5278     NaN       NaN     NaN     NaN     NaN      NaN
# 2000  0.5378  0.5267     NaN       NaN     NaN     NaN     NaN      NaN
# 2100    0.55  0.5256     NaN       NaN     NaN     NaN     NaN      NaN
# 2200  0.5333  0.5167     NaN       NaN     NaN     NaN     NaN      NaN
# 2300    0.55  0.5344     NaN       NaN     NaN     NaN     NaN      NaN
# 2400  0.5344  0.5144     NaN       NaN     NaN     NaN     NaN      NaN
# 2500    0.54  0.5211     NaN       NaN     NaN     NaN     NaN      NaN
# 2600  0.5578  0.5267     NaN       NaN     NaN     NaN     NaN      NaN
# 2700  0.5489  0.5311     NaN       NaN     NaN     NaN     NaN      NaN
# 2800  0.5678  0.5478  0.3969     0.345  0.6755  0.4141  0.6716  0.49138
# 2900  0.5544  0.5322     NaN       NaN     NaN     NaN     NaN      NaN
# 3000  0.5356  0.5167     NaN       NaN     NaN     NaN     NaN      NaN
#
#      infographics_w_ocr infographics mmbench
# 100                 NaN          NaN     NaN
# 200                 NaN          NaN     NaN
# 300                 NaN          NaN     NaN
# 400                 NaN          NaN     NaN
# 500                 NaN          NaN     NaN
# 600                 NaN          NaN     NaN
# 700                 NaN          NaN     NaN
# 800                 NaN          NaN     NaN
# 900                 NaN          NaN     NaN
# 1000                NaN          NaN     NaN
# 1100                NaN          NaN     NaN
# 1200                NaN          NaN     NaN
# 1300                NaN          NaN     NaN
# 1400                NaN          NaN     NaN
# 1500                NaN          NaN     NaN
# 1600                NaN          NaN     NaN
# 1700                NaN          NaN     NaN
# 1800                NaN          NaN     NaN
# 1900                NaN          NaN     NaN
# 2000                NaN          NaN     NaN
# 2100                NaN          NaN     NaN
# 2200                NaN          NaN     NaN
# 2300                NaN          NaN     NaN
# 2400                NaN          NaN     NaN
# 2500                NaN          NaN     NaN
# 2600                NaN          NaN     NaN
# 2700                NaN          NaN     NaN
# 2800             0.5826       0.4113  0.5775
# 2900                NaN          NaN     NaN
# 3000                NaN          NaN     NaN

# %% [markdown]
# # S1 norm

# %%
OUTPUT_S1_norm = "/fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2"
# BENCHMARKS = ["mathvista", "vqa"]
BENCHMARKS = ["mmmu"]

# %%
# ev.run_eval_sweep(
ev_prod.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm,
    benchmarks=["mmmu"],
    slurm_qos="midpri",
    update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-100
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 100
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-100.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-200
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 200
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-200.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-300
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 300
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-300.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-400
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 400
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-400.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-500
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 500
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-500.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-600
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 600
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-600.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-700
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 700
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-700.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-800
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 800
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-800.json
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-900
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/experiments/eval/sbash_eval.sh /fsx_0/user/tranx/aws_prod /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 900
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-900.json
# Will not launch more jobs due to exceeding max_num_jobs=10.

# %%
ev_master.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm,
    benchmarks=["mmmu"],
    slurm_qos="midpri",
    checkpoints=[100],
    update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [100]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/checkpoint-100
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm9_sft/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm mmmu 100
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm/evals/eval_jobs_checkpoint-100.json

# %%
ev_master.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm,
    benchmarks=["mmmu"],
    slurm_qos="midpri",
    min_checkpoint=5600,
    # checkpoints=[3600],
    # update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: []

# %%
ev_master.get_scores(OUTPUT_S1_norm, min_checkpoint=5000)
# Out:
#      mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 5100  0.5711  0.5444     NaN       NaN     NaN     NaN     NaN      NaN
# 5200    0.58  0.5611  0.4887     0.375  0.7733  0.4246  0.6872  0.57886
# 5300  0.5744  0.5522     NaN       NaN     NaN     NaN     NaN      NaN
# 5400  0.5611  0.5456     NaN       NaN     NaN     NaN     NaN      NaN
# 5500  0.5444  0.5256     NaN       NaN     NaN     NaN     NaN      NaN
# 5600  0.5511  0.5344     NaN       NaN     NaN     NaN     NaN      NaN
# 5700  0.5556  0.5411     NaN       NaN     NaN     NaN     NaN      NaN
# 5800  0.5733  0.5522     NaN       NaN     NaN     NaN     NaN      NaN
# 5900  0.5678  0.5478     NaN       NaN     NaN     NaN     NaN      NaN
#
#      infographics_w_ocr infographics mmbench
# 5100                NaN          NaN     NaN
# 5200             0.6135       0.4783  0.6111
# 5300                NaN          NaN     NaN
# 5400                NaN          NaN     NaN
# 5500                NaN          NaN     NaN
# 5600                NaN          NaN     NaN
# 5700                NaN          NaN     NaN
# 5800                NaN          NaN     NaN
# 5900                NaN          NaN     NaN

# %% [markdown]
# # Non-mmmu

# %%
# eval for non-mmmu
ev_master.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm,
    # benchmarks=["mmmu"],
    benchmarks=benchmark_non_mmmu,
    slurm_qos="midpri",
    checkpoints=[4100],
    update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [4100]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2/checkpoint-4100
# sbatch --parsable --job-name=eval_docvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_docvqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 docvqa 4100
# JOB ID: 37918
# sbatch --parsable --job-name=eval_mathvista --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_mathvista.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 mathvista 4100
# JOB ID: 37919
# sbatch --parsable --job-name=eval_ai2d --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_ai2d.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 ai2d 4100
# JOB ID: 37920
# sbatch --parsable --job-name=eval_chartqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_chartqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 chartqa 4100
# JOB ID: 37921
# sbatch --parsable --job-name=eval_vqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_vqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 vqa 4100
# JOB ID: 37922
# sbatch --parsable --job-name=eval_textvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_textvqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 textvqa 4100
# JOB ID: 37923
# sbatch --parsable --job-name=eval_infographics_w_ocr --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_infographics_w_ocr.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 infographics_w_ocr 4100
# JOB ID: 37924
# sbatch --parsable --job-name=eval_infographics --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_infographics.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 infographics 4100
# JOB ID: 37925
# sbatch --parsable --job-name=eval_mmbench --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_mmbench.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 mmbench 4100
# JOB ID: 37926
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2/evals/eval_jobs_checkpoint-4100.json

# %% [markdown]
# # Norm R3

# %%
OUTPUT_S1_norm_r3 = "/fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3"

# %%
ev_master.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm_r3,
    benchmarks=["mmmu"],
    # benchmarks=eval_helper.ALL_BENCHMARKS,
    slurm_qos="midpri",
    # checkpoints=[100],
    update_if_exists=False,
    print_cmd=True
)
# Out:
# New checkpoints: [6800]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3/checkpoint-6800
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 mmmu 6800 "" ""
# JOB ID: 38329
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3/evals/eval_jobs_checkpoint-6800.json

# %%
# eval for non-mmmu
ev_master.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm_r3,
    # benchmarks=["mmmu"],
    benchmarks=benchmark_non_mmmu,
    slurm_qos="midpri",
    checkpoints=[8900],
    update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [8900]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3/checkpoint-8900
# sbatch --parsable --job-name=eval_docvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_docvqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 docvqa 8900 "" ""
# JOB ID: 38860
# sbatch --parsable --job-name=eval_mathvista --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_mathvista.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 mathvista 8900 "" ""
# JOB ID: 38861
# sbatch --parsable --job-name=eval_ai2d --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_ai2d.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 ai2d 8900 "" ""
# JOB ID: 38862
# sbatch --parsable --job-name=eval_chartqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_chartqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 chartqa 8900 "" ""
# JOB ID: 38863
# sbatch --parsable --job-name=eval_vqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_vqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 vqa 8900 "" ""
# JOB ID: 38864
# sbatch --parsable --job-name=eval_textvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_textvqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 textvqa 8900 "" ""
# JOB ID: 38865
# sbatch --parsable --job-name=eval_infographics_w_ocr --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_infographics_w_ocr.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 infographics_w_ocr 8900 "" ""
# JOB ID: 38866
# sbatch --parsable --job-name=eval_infographics --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_infographics.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 infographics 8900 "" ""
# JOB ID: 38867
# sbatch --parsable --job-name=eval_mmbench --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite/eval_mmbench.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3 mmbench 8900 "" ""
# JOB ID: 38868
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R3/evals/eval_jobs_checkpoint-8900.json

# %%
ev_master.get_scores(OUTPUT_S1_norm_r3)
# Out:
#      mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 5300  0.5644  0.5467  0.4954     0.369  0.7707  0.4193   0.692  0.58598
# 5400  0.5567  0.5389   0.502      0.37  0.7736  0.4271  0.6878  0.58292
# 5500    0.56  0.5444     NaN       NaN     NaN     NaN     NaN      NaN
# 5600  0.5533  0.5322     NaN       NaN     NaN     NaN     NaN      NaN
# 5700    0.55  0.5378     NaN       NaN     NaN     NaN     NaN      NaN
# 5800  0.5733  0.5489     NaN       NaN     NaN     NaN     NaN      NaN
# 5900  0.5622  0.5467     NaN       NaN     NaN     NaN     NaN      NaN
# 6000  0.5733    0.55     NaN       NaN     NaN     NaN     NaN      NaN
# 6100  0.5522  0.5444     NaN       NaN     NaN     NaN     NaN      NaN
# 6200  0.5589    0.54     NaN       NaN     NaN     NaN     NaN      NaN
# 6300  0.5611  0.5433     NaN       NaN     NaN     NaN     NaN      NaN
# 6400  0.5656  0.5589     NaN       NaN     NaN     NaN     NaN      NaN
# 6500  0.5689  0.5533     NaN       NaN     NaN     NaN     NaN      NaN
# 6600  0.5711  0.5522     NaN       NaN     NaN     NaN     NaN      NaN
# 6700    0.55  0.5322     NaN       NaN     NaN     NaN     NaN      NaN
# 6800  0.5356  0.5122     NaN       NaN     NaN     NaN     NaN      NaN
# 6900  0.5744    0.56     NaN       NaN     NaN     NaN     NaN      NaN
# 7000  0.5656  0.5556     NaN       NaN     NaN     NaN     NaN      NaN
# 7100  0.5456  0.5311     NaN       NaN     NaN     NaN     NaN      NaN
# 7200  0.5456  0.5311     NaN       NaN     NaN     NaN     NaN      NaN
# 7300  0.5633  0.5578     NaN       NaN     NaN     NaN     NaN      NaN
# 7400  0.5622    0.55     NaN       NaN     NaN     NaN     NaN      NaN
# 7500  0.5622  0.5478     NaN       NaN     NaN     NaN     NaN      NaN
# 7600  0.5611  0.5467     NaN       NaN     NaN     NaN     NaN      NaN
# 7700  0.5644  0.5378     NaN       NaN     NaN     NaN     NaN      NaN
# 7800    0.55  0.5311     NaN       NaN     NaN     NaN     NaN      NaN
# 7900  0.5411  0.5244     NaN       NaN     NaN     NaN     NaN      NaN
# 8000  0.5411  0.5244     NaN       NaN     NaN     NaN     NaN      NaN
# 8100    0.57  0.5511     NaN       NaN     NaN     NaN     NaN      NaN
# 8200    0.57  0.5544     NaN       NaN     NaN     NaN     NaN      NaN
# 8300  0.5556  0.5422     NaN       NaN     NaN     NaN     NaN      NaN
# 8400  0.5711  0.5489     NaN       NaN     NaN     NaN     NaN      NaN
# 8500  0.5689  0.5467     NaN       NaN     NaN     NaN     NaN      NaN
# 8600  0.5667  0.5533     NaN       NaN     NaN     NaN     NaN      NaN
# 8700    0.57  0.5467     NaN       NaN     NaN     NaN     NaN      NaN
# 8800  0.5511  0.5356     NaN       NaN     NaN     NaN     NaN      NaN
# 8900  0.5811  0.5633  0.4805     0.382  0.7736  0.4533  0.6923  0.57818
# 9000  0.5533  0.5389     NaN       NaN     NaN     NaN     NaN      NaN
# 9100  0.5556  0.5356     NaN       NaN     NaN     NaN     NaN      NaN
# 9200  0.5733  0.5456     NaN       NaN     NaN     NaN     NaN      NaN
# 9300  0.5767  0.5544     NaN       NaN     NaN     NaN     NaN      NaN
# 9400  0.5689  0.5567     NaN       NaN     NaN     NaN     NaN      NaN
# 9500  0.5711  0.5589     NaN       NaN     NaN     NaN     NaN      NaN
# 9600  0.5656  0.5489     NaN       NaN     NaN     NaN     NaN      NaN
# 9700  0.5322  0.5189     NaN       NaN     NaN     NaN     NaN      NaN
# 9800    0.56  0.5489     NaN       NaN     NaN     NaN     NaN      NaN
#
#      infographics_w_ocr infographics mmbench
# 5300             0.6148       0.4674  0.6037
# 5400             0.6169       0.4667  0.6263
# 5500                NaN          NaN     NaN
# 5600                NaN          NaN     NaN
# 5700                NaN          NaN     NaN
# 5800                NaN          NaN     NaN
# 5900                NaN          NaN     NaN
# 6000                NaN          NaN     NaN
# 6100                NaN          NaN     NaN
# 6200                NaN          NaN     NaN
# 6300                NaN          NaN     NaN
# 6400                NaN          NaN     NaN
# 6500                NaN          NaN     NaN
# 6600                NaN          NaN     NaN
# 6700                NaN          NaN     NaN
# 6800                NaN          NaN     NaN
# 6900                NaN          NaN     NaN
# 7000                NaN          NaN     NaN
# 7100                NaN          NaN     NaN
# 7200                NaN          NaN     NaN
# 7300                NaN          NaN     NaN
# 7400                NaN          NaN     NaN
# 7500                NaN          NaN     NaN
# 7600                NaN          NaN     NaN
# 7700                NaN          NaN     NaN
# 7800                NaN          NaN     NaN
# 7900                NaN          NaN     NaN
# 8000                NaN          NaN     NaN
# 8100                NaN          NaN     NaN
# 8200                NaN          NaN     NaN
# 8300                NaN          NaN     NaN
# 8400                NaN          NaN     NaN
# 8500                NaN          NaN     NaN
# 8600                NaN          NaN     NaN
# 8700                NaN          NaN     NaN
# 8800                NaN          NaN     NaN
# 8900             0.6162       0.4744   0.624
# 9000                NaN          NaN     NaN
# 9100                NaN          NaN     NaN
# 9200                NaN          NaN     NaN
# 9300                NaN          NaN     NaN
# 9400                NaN          NaN     NaN
# 9500                NaN          NaN     NaN
# 9600                NaN          NaN     NaN
# 9700                NaN          NaN     NaN
# 9800                NaN          NaN     NaN

# %% [markdown]
# # Testing

# %%
ev_test = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync",
    eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02"
)

OUTPUT_MAIN_32 = "/fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px"

# %%
ev_test.get_scores(OUTPUT_MAIN_32)
# Out:
# Empty DataFrame
# Columns: [mmmu_v2, mmmu_v1, docvqa, mathvista, ai2d, chartqa, vqa, textvqa, infographics_w_ocr, infographics, mmbench]
# Index: []

# %%
ev_test.run_eval_sweep(
    checkpoint_dir=OUTPUT_S1_norm,
    # benchmarks=["mmmu"],
    benchmarks=benchmark_non_mmmu,
    slurm_qos="midpri",
    # min_checkpoint=4300,
    checkpoints=[5200],
    update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [5200]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2/checkpoint-5200
# sbatch --parsable --job-name=eval_docvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_docvqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 docvqa 5200
# JOB ID: 37943
# sbatch --parsable --job-name=eval_mathvista --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_mathvista.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 mathvista 5200
# JOB ID: 37944
# sbatch --parsable --job-name=eval_ai2d --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_ai2d.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 ai2d 5200
# JOB ID: 37945
# sbatch --parsable --job-name=eval_chartqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_chartqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 chartqa 5200
# JOB ID: 37946
# sbatch --parsable --job-name=eval_vqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_vqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 vqa 5200
# JOB ID: 37947
# sbatch --parsable --job-name=eval_textvqa --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_textvqa.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 textvqa 5200
# JOB ID: 37948
# sbatch --parsable --job-name=eval_infographics_w_ocr --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_infographics_w_ocr.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 infographics_w_ocr 5200
# JOB ID: 37949
# sbatch --parsable --job-name=eval_infographics --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_infographics.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 infographics 5200
# JOB ID: 37950
# sbatch --parsable --job-name=eval_mmbench --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_f587797729-watcher-2024-08-02/eval_mmbench.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2 mmbench 5200
# JOB ID: 37951
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2/evals/eval_jobs_checkpoint-5200.json

# %%
ev_test.get_scores(OUTPUT_S1_norm, checkpoints=[5200])
# Out:
#      mmmu_v2 mmmu_v1  docvqa mathvista    ai2d chartqa     vqa  textvqa  \
# 5200    0.58  0.5611  0.4887     0.375  0.7733  0.4246  0.6872  0.57886
#
#      infographics_w_ocr infographics mmbench
# 5200             0.6135       0.4783  0.6111

# %% [markdown]
# # Tiktoken v4

# %%
OUTPUT_v4 = "/fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2_v4"
OUTPUT_v5 = "/fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2_v5"

# %%
ev_v4 = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync",
    eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_v4"
)

ev_v4.run_eval_sweep(
    checkpoint_dir=OUTPUT_v4,
    benchmarks=["mmmu"],
    slurm_qos="midpri",
    # checkpoints=[5200],
    # eval_plan="evals_v4",
    # update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: [5200]
# Start eval for /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2_v4/checkpoint-5200
# sbatch --parsable --job-name=eval_mmmu --qos=midpri --account=midpri /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh /fsx_0/user/tranx/rsync /fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_v4/eval_mmmu.json /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2_v4 mmmu 5200 "" ""
# JOB ID: 38010
# eval jobs saved to: /fsx_0/checkpoints/mm10/MM10-Stage1-70B/MH21_70B_224px_norm_R2_v4/evals/eval_jobs_checkpoint-5200.json

# %%
ev_v4.get_scores(OUTPUT_v4)
# Out:
#      mmmu_v2 mmmu_v1 docvqa mathvista ai2d chartqa  vqa textvqa  \
# 5200  0.5344  0.5044    NaN       NaN  NaN     NaN  NaN     NaN
#
#      infographics_w_ocr infographics mmbench
# 5200                NaN          NaN     NaN

# %% [markdown]
# # Tiktoken v5

# %%
ev_v5 = eval_helper.EvalHelper(
    code_dir="/fsx_0/user/tranx/rsync",
    eval_sbatch="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/launch_eval_sbatch.sh",
    eval_config_dir="/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage1/eval_overwrite_v5"
)

# %%
ev_v5.run_eval_sweep(
    checkpoint_dir=OUTPUT_v5,
    benchmarks=["mmmu"],
    slurm_qos="midpri",
    # checkpoints=[5200],
    # eval_plan="evals_v4",
    # update_if_exists=True,
    print_cmd=True
)
# Out:
# New checkpoints: []

# %%
ev_v5.get_scores(OUTPUT_v5)
# Out:
#      mmmu_v2 mmmu_v1 docvqa mathvista ai2d chartqa  vqa textvqa  \
# 5200  0.5611  0.5422    NaN       NaN  NaN     NaN  NaN     NaN
#
#      infographics_w_ocr infographics mmbench
# 5200                NaN          NaN     NaN

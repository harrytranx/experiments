# %%
import json 
from collections import OrderedDict
import glob
import webdataset as wds
from torch.utils.data import DataLoader
from pprint import pprint
import os

# %%
def read_json(file):
    with open(file, 'r') as f:
        # data = json.load(f)
        data = json.load(f, object_pairs_hook=OrderedDict)
        
    return data 

def load_sample_simple(sample):
    data = {}
    json_data = json.loads(sample["json"])
    for k, v in json_data.items():
        if v is not None:
            data[k] = v 
            
    image_keys = ['jpg', 'png', 'jpeg', 'bmp', 'tif', 'tiff']
    for k in image_keys:
        if k in sample:
            data["image_key"] = k 
            break 
    
    # # specical for instruction_tune
    # data.update(
    #     {
    #         "question": json_data.get("question", ""),
    #         "response": json_data.get("response", ""),
    #         "instruction": json_data.get("instruction", ""),
    #     }
    # )
    
    # if "response" not in json_data and "text" in json_data:
    #     data["response"] = data["text"]
                
    return data 

def test_wds_iterator(wd_path, num_samples=1):
    search_path = os.path.join(wd_path, "**", "*.tar")
    train_urls = glob.glob(search_path, recursive=True)
    
    # files = glob.glob(wd_path + '/**/*', recursive=True)
    
    dataset = wds.DataPipeline(
        wds.SimpleShardList(train_urls),
        wds.tariterators.tarfile_to_samples(),
        wds.map(load_sample_simple)
    )
    
    dataloader = DataLoader(dataset, batch_size=1, num_workers=0)
    
    for i, sample in enumerate(dataloader):
        if i == num_samples:
            break 
        
        pprint(sample)

# %%
config_json = "/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/MH21_70B_224px_0916_exp32a_20240927.json"
config = read_json(config_json)

wd_data_path = config['trainer_args']['wd_data_path']
print(wd_data_path) 

verification_results = {}

for path in wd_data_path:
    path = path.split(":")[0]
    print(f"Testing: {path}")
    try:
        test_wds_iterator(path)
        verification_results[path] = True
    except Exception as e:
        print(e)
        verification_results[path] = False
# Out:
# ['/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted', '/fsx_0/user/yetian12/datasets/idl-wds_v2', '/fsx_1/datasets_30days/sg_mmllm_stage_2_exp31a/20240905', '/fsx_0/datasets_30days/flywheel/sg_mmllm_sft_sg_data_curation_flywheel_6p8k_0916:300', '/fsx_1/datasets_30days/sg_mmllm_stage_2_exp32a_subtable_ocr', '/fsx_1/datasets_30days/sg_mmllm_stage_2_exp32a_subtable_sg_qa', '/fsx_1/datasets_30days/datarecipe_source/sg_mmllm_stage2_compliant_cap_qa_exp28_kosher_v2/20240827v4/sg_mmllm_coco_captions_blur', '/fsx_1/datasets_30days/datarecipe_source/sg_mmllm_stage2_compliant_cap_qa_exp28_kosher_v2/20240827v4/sg_mmllm_coco_object_count_rewritten_cap_46k:25', '/fsx_1/datasets_30days/mmllm_m2c2_mitigated_id_inc_filtered_clip_0_36_unique_id']
# Testing: /fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted
# {'__key__': ['0004531-0'],
#  'image_key': ['png'],
#  'text': ['Pliocene Ridge Community Services District Policies & Procedures: '
#           'OPERATIONS Policy 3015 NON-DISCRIMINATION/AFFIRMATIVE ACTION The '
#           'Pliocene Ridge Community Services District is an equal opportunity '
#           'employer and is committed to an active nondiscrimination program. '
#           'It is the stated policy of the District that all employees and '
#           'applicants shall receive equal consideration and treatment. As a '
#           'primarily volunteer based organization the District encourages '
#           'participation by all community members at ALL times. Exceptions do '
#           'apply when certain physical requirements are necessary for the '
#           'safety of all involved. Recruitment, hiring, placement, transfers '
#           'and promotions shall be based on the qualifications of the '
#           'individual for the position being filled regardless of race, color, '
#           'religion, ancestry, national origin, age (over 40 years), sex, '
#           'sexual-orientation, marital status, medical condition or physical '
#           'handicap. (First Responders must meet certain physical requirements '
#           'due to the nature of the job). All other personnel actions such as '
#           'compensation, training, and social events are provided regardless '
#           'of race, color, religion, ancestry, national origin, age (over 40 '
#           'years), sex, sexual-orientation marital status, medical condition '
#           "or physical handicap. The objective of the District's "
#           'nondiscrimination program is to ensure that all participants are '
#           'treated equally and fairly and to encourage volunteerism from all '
#           'segments of the community. AFFIRMATIVE ACTION All decisions on '
#           "employment and promotion must be made solely on the individual's "
#           'qualifications (merit) and bona fide occupational qualifications '
#           'for the job in question and the feasibility of any necessary job '
#           "accommodations. To achieve the goals of the District's "
#           'nondiscrimination program, it is necessary that each employee '
#           '(volunteer) understand the importance of the program and his/her '
#           'individual responsibility to contribute to its maximum fulfillment. '
#           'This policy is an integral part of the District’s Personnel Policy '
#           'Manual given to all volunteers and reviewed periodically by the '
#           'crews of both the Alleghany and Pike Volunteer Fire Departments. '
#           'The District Board shall review and reaffirm this policy statement '
#           'annually. Version 2 Adopted April 17, 2019 Page 1 of 1 Policy # '
#           '3015']}
# Testing: /fsx_0/user/yetian12/datasets/idl-wds_v2
# {'__key__': ['ffbb0107-0'],
#  'image_key': ['jpg'],
#  'text': ['BASIC WEIGHT SPECIFICATION COPY EFFECTIVE DATE: January 5, 1982 '
#           "BRAND BENI L'IGHTS 100'S REGULAR S.P. PRODUCT CODE 510 LOCATION "
#           'LOUISVILLE LENGTH TOBACCO ROO 68 TIPPING*LENCTH 36. Oilini '
#           'CIGARETTE PAPER WIDTH 27.0mm PACK MOISTURE: 12.65% ROO MOISTURE: '
#           "FILLER: DESCRIPTION BCH Lights 100's Reg. E.T. 10.0% È.S.B. 1 4.8% "
#           'MAX E.S. 8.252 ADJUSTHENTS: E.T. 4.9 % DECREASE E.S. 2.9 % DECREASE '
#           'R.L. .8125 2 INCREASE MENTHOL 0 % INCREASE OTHER FLAVOR .25 % '
#           'DECREASE DENSITY: BASE 25.94094 (Coms./CC) ADJUSTED 24.0635 '
#           '(Cgms./cc) WEIGHTS: FILLER 8008673 (Gms. ) 1.7656 (Lbs./1000) '
#           'PAPER/PASTE :0468747 ROD WEIGHT .8477420 TIPPING E ADHESIVE '
#           '.0510342 TOTAL LESS PLUG 8987762 REASON FOR CHANGE: BLEND CHANGES '
#           'SUPERSEDES SPECIFICATION DATED: January 13, 1981 2031305528 '
#           'PREPARED Debble J. Morgan DE Aames 2 mennie see']}
# Testing: /fsx_1/datasets_30days/sg_mmllm_stage_2_exp31a/20240905
# {'__key__': ['0069_0000022900000'],
#  'ds': ['2024-08-27'],
#  'image_key': ['png'],
#  'image_manifold_path': ['manifold://sg_scene_ai/tree/llm_mm_aligner/datasets/VAQ_RAD/VQA_RAD '
#                          'Image Folder/synpic27142.jpg'],
#  'instruction': ['\nProvide a single word or phrase as your answer.'],
#  'question': ['Where are the hyperintensities located?'],
#  'response': ['"Cortical ribbon of right occipital lobe with extension into '
#               'right posterior temporal lobe"'],
#  'shard_id': tensor([639970]),
#  'source_table': ['sg_mmllm_stage_2_exp31a_subtable_pathvqa_theoremqa_combined_10x/ds=2024-08-27']}
# Testing: /fsx_0/datasets_30days/flywheel/sg_mmllm_sft_sg_data_curation_flywheel_6p8k_0916
# {'__key__': ['0099_0000000000000'],
#  'ds': ['2024-09-16'],
#  'everstore_handle': ['GK_uiALYnH86u5ACAAAAAAAgiH5lbkULAAAB'],
#  'image_key': ['png'],
#  'instruction': ['Answer the question using a single word or a continuous '
#                  'phrase from the image.\n'
#                  'The phase can span multiple lines.\n'
#                  'The phrase is less than 15 words.'],
#  'keep': tensor([True]),
#  'question': ['What does it say under thymus when you have zinc deficiency?'],
#  'response': ['Thymic atrophy'],
#  'shard_id': tensor([99]),
#  'source_table': ['mmai_ig_curated_v1_0916/ds=2024-09-16']}
# Testing: /fsx_1/datasets_30days/sg_mmllm_stage_2_exp32a_subtable_ocr
# {'__key__': ['0030_0000007300000'],
#  'image_key': ['jpg'],
#  'image_manifold_path': ['manifold://vlm/tree/tripple-ocr/000041/000041000812.png'],
#  'response': ['concerning reform of the House of Lords. In its 217-page '
#               'report'],
#  'shard_id': tensor([1004330])}
# Testing: /fsx_1/datasets_30days/sg_mmllm_stage_2_exp32a_subtable_sg_qa
# {'__key__': ['0054_0000003700000'],
#  'image_key': ['jpg'],
#  'image_manifold_path': ['manifold://sg_scene_ai/tree/llm_mm_aligner/datasets/dvqa/images/bar_train_00111192.png'],
#  'instruction': ['\nAnswer the question using a single word.'],
#  'question': ['What is the accuracy of the algorithm meat in the dataset '
#               'profit?'],
#  'response': ['60'],
#  'shard_id': tensor([1292654])}
# Testing: /fsx_1/datasets_30days/datarecipe_source/sg_mmllm_stage2_compliant_cap_qa_exp28_kosher_v2/20240827v4/sg_mmllm_coco_captions_blur
# {'__key__': ['0049_0000193800000'],
#  'image_key': ['png'],
#  'image_manifold_path': ['manifold://sg_scene_ai/tree/llm_mm_aligner/coco/train2014/COCO_train2014_000000544410.jpg'],
#  'response': ['A large birthday cake form placed on the sidewalk']}
# Testing: /fsx_1/datasets_30days/datarecipe_source/sg_mmllm_stage2_compliant_cap_qa_exp28_kosher_v2/20240827v4/sg_mmllm_coco_object_count_rewritten_cap_46k
# {'__key__': ['0051_0000015400000'],
#  'image_key': ['png'],
#  'image_manifold_path': ['manifold://sg_scene_ai/tree/llm_mm_aligner/coco/train2017/000000237247.jpg'],
#  'response': ['A person wearing a plaid shirt and jeans stands on a skateboard '
#               'on a ramp, while a few people watch from a distance, with a '
#               'towering observatory in the background.']}
# Testing: /fsx_1/datasets_30days/mmllm_m2c2_mitigated_id_inc_filtered_clip_0_36_unique_id
# {'__key__': ['0073_0000021500000'],
#  'id_inc': tensor([21500073]),
#  'image_key': ['jpg'],
#  'image_manifold_path': ['manifold://sg_scene_ai/tree/metaclip/untar/90/173090/473146d7bd67e4d5b5a223b6.jpeg'],
#  'similarity_score': tensor([0.3871], dtype=torch.float64),
#  'text': ['2021 Reformation Heritage Conference tickets']}

# %%
verification_results
# Out:
# {'/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted': True,
#  '/fsx_0/user/yetian12/datasets/idl-wds_v2': True,
#  '/fsx_1/datasets_30days/sg_mmllm_stage_2_exp31a/20240905': True,
#  '/fsx_0/datasets_30days/flywheel/sg_mmllm_sft_sg_data_curation_flywheel_6p8k_0916': True,
#  '/fsx_1/datasets_30days/sg_mmllm_stage_2_exp32a_subtable_ocr': True,
#  '/fsx_1/datasets_30days/sg_mmllm_stage_2_exp32a_subtable_sg_qa': True,
#  '/fsx_1/datasets_30days/datarecipe_source/sg_mmllm_stage2_compliant_cap_qa_exp28_kosher_v2/20240827v4/sg_mmllm_coco_captions_blur': True,
#  '/fsx_1/datasets_30days/datarecipe_source/sg_mmllm_stage2_compliant_cap_qa_exp28_kosher_v2/20240827v4/sg_mmllm_coco_object_count_rewritten_cap_46k': True,
#  '/fsx_1/datasets_30days/mmllm_m2c2_mitigated_id_inc_filtered_clip_0_36_unique_id': True}

# %% [markdown]
# # Test wds

# %%
import re 
import random 

def _get_sampling_multiplier(path: str) -> tuple[str, float]:
    """Split path and get sampling multiplier, if it exists.
    :param path: path with or without a sampling multiplier
    :return: path without the multiplier, sampling multiplier or None
    Examples:
        _get_sampling_multiplier("foo") -> "foo", 1.0
        _get_sampling_multiplier("foo:0.5") -> "foo", 0.5
        _get_sampling_multiplier("foo:1.5") -> "foo", 1.5
        _get_sampling_multiplier("foo:2") -> "foo", 2.0
    """
    pattern = r"^[^\s:]+\:(\d*\.)?\d+$"
    match = re.search(pattern, path)
    if match:
        path, multiplier = path.split(":")
        return (path, float(multiplier))
    path = path.split(" ")[0].split(":")[0].strip()
    return (path, 1.0)

def _update_data_filters(
    wd_train_urls: list[str],
    data_filters: dict[str, dict],
    dataset_config: dict[str, dict],
) -> None:
    """Update data filters for each tar file url"""
    for url in wd_train_urls:
        data_filters[url] = {
            "target_keys": dataset_config.get("target_keys", None),
            "rename_map": dataset_config.get("rename_map", None),
        }
        
def _get_train_urls_from_datarecipe(
    wd_datarecipe: dict[str, dict],
    data_seed: int | None,
) -> tuple[list[str], dict[str, dict]]:
    """Get train urls from wd_datarecipe.
    Args:
        wd_datarecipe: a mixture of data sources, w/o a sampling multiplier
        data_seed: random seed to use for sampling or None
    Returns:
        train_urls: list of paths
        data_filters: dict of data filters for each url
    Examples:
        "wd_datarecipe": {
            "dataset1": {
                "path": 'path3',                        # required, str or list
                "chunk_size": 1000,                     # required, int
                "multiplier": 2,                        # optional, int, float, or list, default=1,
                "target_keys": ["caption", "response"], # optional, default to load all
                "rename_map": {"caption": "text"}       # optional, default with no rename
            },
            "dataset2": {
                "path": ['/path4', '/path5']            # required, str or list
                "chunk_size": 1000,                     # required, int
                "multiplier": [0.5, 2],                 # optional, int, float, or list, default=1,
                "target_keys": ["caption", "response"], # optional, default to load all
                "rename_map": {"caption": "text"}       # optional, default with no rename
            },
        }
    """
    train_urls = []
    data_filters = {}

    for dataset_name, dataset_config in wd_datarecipe.items():
        path = dataset_config.get("paths", None)
        if not path:
            raise ValueError(f"Missing path for dataset {dataset_name}")

        # datasets with single path
        if isinstance(path, str):
            multiplier = dataset_config.get("multiplier", 1.0)
            wd_train_urls = _sample_webds_dataset(
                path,
                multiplier,
                data_seed,
            )
            train_urls.extend(wd_train_urls)
            _update_data_filters(list(set(wd_train_urls)), data_filters, dataset_config)

        # datasets with multiple paths
        elif isinstance(path, list):
            multipliers = dataset_config.get("multiplier", [1.0] * len(path))

            # make multipliers the same length as path
            if len(multipliers) != len(path):
                raise ValueError(
                    "number of multipliers must be less than or equal to the number of paths"
                )

            for single_path, multiplier in zip(path, multipliers):
                wd_train_urls = _sample_webds_dataset(
                    single_path,
                    multiplier,
                    data_seed,
                )
                train_urls.extend(wd_train_urls)
                # each url has unique data filters
                _update_data_filters(
                    list(set(wd_train_urls)), data_filters, dataset_config
                )
        else:
            raise ValueError(
                f"Invalid type for path in dataset {dataset_name}. Expected str or list, got {type(path)}."
            )
    return (train_urls, data_filters)


def _sample_webds_dataset(
    path: str, multiplier: float, data_seed: int | None
) -> list[str]:
    """Sample the dataset based on the multiplier.

    :param path: tar file url
    :param multiplier: sampling multiplier
        when float between 0.0 and 1.0, subsample
        when integer >= 1, oversample
        when float > 1.0, oversample + random sample
    :param data_seed: random seed to use for sampling or None
        when not None, initialize random sampler with the specified seed
        when None, initialize random sampler with seed=0
    """
    if multiplier <= 0.0:
        raise ValueError("wd_data_sampling_multiplier must be greater than 0.0")

    search_path = os.path.join(path, "**", "*.tar")
    train_urls = glob.glob(search_path, recursive=True)

    rand = random.Random(data_seed or 0)
    if multiplier < 1.0:
        # subsampling the data
        train_urls = rand.sample(train_urls, int(len(train_urls) * multiplier))
    elif multiplier.is_integer():
        # oversampling the data, when multplier is 1, 2, 3...
        train_urls = train_urls * int(multiplier)
    else:
        # oversampling the data + random sampling when multiplier is 1.5, 2.7, 3.1...
        q, r = divmod(multiplier, 1)
        train_urls = train_urls * int(q) + rand.sample(
            train_urls, int(len(train_urls) * r)
        )
    return train_urls

def _get_train_urls(
    wd_data_path: str | list[str] | None,
    wd_datarecipe: dict[str, dict] | None,
    data_seed: int | None,
) -> tuple[list[str], dict[str, dict]]:
    train_urls = []
    data_filters = {}
    if not wd_data_path and not wd_datarecipe:
        return train_urls, data_filters

    if wd_data_path:
        if isinstance(wd_data_path, list):
            path_list = wd_data_path
        else:
            path_list = wd_data_path.split(",")
        for path in path_list:
            path, multiplier = _get_sampling_multiplier(path.strip())
            wd_train_urls = _sample_webds_dataset(
                path,
                multiplier,
                data_seed,
            )
            train_urls.extend(wd_train_urls)

    if wd_datarecipe:
        wd_train_urls, data_filters = _get_train_urls_from_datarecipe(
            wd_datarecipe, data_seed
        )
        train_urls.extend(wd_train_urls)
    return train_urls, data_filters

# %%
config_json = "/fsx_0/user/tranx/rsync/llm_mm_aligner/experiments/aws/mm10/stage2/MH21_70B_336px_exp32a_20240930.json"
config = read_json(config_json)

wd_data_path = config['trainer_args']['wd_data_path']

train_urls, data_filters = _get_train_urls(wd_data_path, None, None)

# %%
train_urls
# Out:
# ['/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0897.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0342.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1502.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1163.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0084.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0723.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0055.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1615.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1274.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0846.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0434.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0393.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0171.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1096.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1731.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1350.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0510.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0962.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0266.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1426.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1381.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1047.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0607.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0499.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0029.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1669.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1208.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0448.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1736.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1091.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0176.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0965.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0517.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1357.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1386.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1421.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0261.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0600.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1040.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1579.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0339.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0758.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1118.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0789.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0919.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1505.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0345.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0890.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0724.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0083.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1164.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1612.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0052.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0394.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0433.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0841.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1273.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0178.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1738.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1359.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0519.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1388.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0490.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0337.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1577.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1116.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0756.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0020.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0787.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1660.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1201.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0441.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0833.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0104.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1744.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1482.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1325.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0917.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0565.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0213.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1453.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1032.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1795.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0672.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1743.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0103.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0562.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0910.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1322.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1485.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1454.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0214.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0675.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1792.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1035.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0899.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0848.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1098.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1428.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0268.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0609.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1049.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1570.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0330.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0497.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0751.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1111.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1667.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0780.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0027.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0834.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0446.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1206.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0640.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1000.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1461.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0221.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0586.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0557.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0925.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1317.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1776.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0691.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0136.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1189.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0718.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1158.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1539.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0379.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0988.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0959.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0801.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0473.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1233.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1594.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1652.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0012.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0764.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1683.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1124.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1545.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0305.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1593.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1234.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0474.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0806.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0015.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1655.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1123.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1684.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0763.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0302.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1542.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1007.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0647.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0581.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0226.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1466.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1310.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0922.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0550.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0131.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0696.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1771.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1248.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0408.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0069.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1629.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1299.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0635.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0192.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1075.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1414.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0254.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0981.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0285.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0950.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0522.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1362.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1703.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0143.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0808.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0649.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1009.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1468.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0228.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0698.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0406.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0874.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1246.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1627.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1180.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0067.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0711.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1151.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1297.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1530.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0370.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0588.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1319.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0559.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0138.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1778.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1241.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0873.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0401.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0060.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1187.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1620.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1156.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0716.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0377.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1537.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1290.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1072.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0195.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0632.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0986.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0253.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1413.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1365.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0525.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0957.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0282.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0144.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1704.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1147.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0707.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0366.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1281.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1526.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1250.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0410.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0862.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0071.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1631.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1196.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1308.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0548.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0129.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1769.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0599.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1374.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0293.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0946.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0534.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0155.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1715.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1063.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0623.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0184.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0242.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0997.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1402.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0819.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0533.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0941.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0294.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1373.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1712.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0152.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0183.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0624.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1064.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1405.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0990.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0245.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0700.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1140.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1521.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1286.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0361.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0865.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0417.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1257.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1191.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1636.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0076.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0689.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0658.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1018.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1479.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0239.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1695.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1132.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0772.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0313.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1553.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1225.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1582.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0817.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0465.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0004.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1644.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1288.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1259.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0419.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0078.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1638.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1301.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0541.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0933.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0687.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0120.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1760.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1016.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0656.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0237.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0590.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1477.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0709.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1149.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1528.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0368.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1198.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0934.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0546.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1306.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1767.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0127.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0680.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0651.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1011.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1470.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0597.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0230.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0775.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1135.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1692.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1554.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0314.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0462.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0810.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1585.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1222.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1643.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0003.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0948.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0999.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0859.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0888.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1445.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0205.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0664.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1024.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1783.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1752.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0112.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0901.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0573.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1494.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1333.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1676.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0036.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0791.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0457.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0825.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1217.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1561.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0486.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0321.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0740.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1100.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1439.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0279.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0618.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1058.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1089.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0796.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0031.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1671.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1210.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0822.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0450.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0326.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0481.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1566.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1107.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0747.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1399.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0169.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1729.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1348.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0508.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0202.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1442.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1784.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1023.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0663.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0115.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1755.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1334.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1493.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0574.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0906.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0798.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1568.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0328.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0749.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1109.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1430.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1397.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0270.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0611.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1051.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1080.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1727.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0167.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0506.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0974.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1346.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1603.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0043.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0850.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0422.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0385.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1262.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1514.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0881.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0354.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0092.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0735.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1175.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0908.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0044.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1604.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1265.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0382.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0425.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0857.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0353.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0886.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1513.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1172.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0732.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0095.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0038.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1678.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1219.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0459.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0488.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0277.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1390.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1437.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1056.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0616.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0160.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1720.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1087.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1341.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0973.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0501.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0589.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1318.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0558.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0139.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1779.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1240.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0872.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0400.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0061.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1621.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1186.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1157.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0717.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0376.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1291.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1536.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1073.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0633.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0194.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0252.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0987.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1412.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1364.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0283.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0524.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0956.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0145.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1705.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0193.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0634.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1074.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1415.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0980.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0255.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0951.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0523.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0284.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1363.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1702.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0142.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0809.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0648.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1008.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1469.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0229.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0699.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0407.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0875.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1247.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1181.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1626.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0066.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0710.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1150.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1531.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1296.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0371.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1235.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1592.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0475.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0807.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0014.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1654.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1685.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1122.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0762.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0303.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1543.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1006.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0646.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0227.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0580.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1467.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1311.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0923.tar',
# ...
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1583.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1224.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0816.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0464.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0005.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1645.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1289.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1258.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0418.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0079.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1639.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1300.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0540.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0932.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0121.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0686.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1761.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1017.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0657.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0591.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0236.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1476.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0818.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0295.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0532.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0940.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1372.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1713.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0153.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0625.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0182.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1065.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1404.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0244.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0991.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0701.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1141.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1287.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1520.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0360.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0864.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0416.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1256.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1637.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1190.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0077.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0688.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0659.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1019.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1478.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0238.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1146.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0706.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0367.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1527.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1280.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1251.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0411.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0863.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0070.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1197.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1630.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1309.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0549.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0128.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1768.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0598.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1375.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0947.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0535.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0292.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0154.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1714.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1062.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0185.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0622.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0996.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0243.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1403.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1053.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0613.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0272.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1395.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1432.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1344.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0976.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0504.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0165.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1725.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1082.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1260.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0387.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0420.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0852.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0041.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1601.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1177.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0737.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0090.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0356.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0883.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1516.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1788.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1338.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0578.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0119.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1759.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0855.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0427.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0380.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1267.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1606.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0046.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0097.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0730.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1170.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1511.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0884.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0351.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0668.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1028.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1449.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0209.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1498.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0829.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0614.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1054.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1435.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1392.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0275.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0503.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0971.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1343.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1085.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1722.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0162.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1269.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0429.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0048.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1608.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0099.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1781.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1026.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0666.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0207.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1447.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1331.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1496.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0571.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0903.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0110.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1750.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1215.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0827.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0455.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0793.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0034.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1674.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1102.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0742.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0323.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0484.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1563.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0452.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0820.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1212.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1673.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0033.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0794.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0745.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1105.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-1564.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0483.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0324.tar',
#  '/fsx_0/user/yetian12/datasets/pdfa-eng-wds-converted/converted_pdfa-eng-train-0978.tar',
#  ...]

# %%
"wd_datarecipe": [
	"dataset1": {
		"path": 'path1', #required, str or list
		"chunk_size": 1000, #required, str or list
		"multiplier": 2 # optional, default=1, must be same as length as path if provided
		"target_keys": ["caption", "response"], # optional, default load all
		"rename_keys": {"caption": "text"} # optional, default no rename
       },
]
